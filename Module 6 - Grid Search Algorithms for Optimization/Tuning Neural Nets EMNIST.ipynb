# %%
import numpy as np
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# Get gpu, mps or cpu device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
def get_train_valid_loader(data_dir,
                           batch_size,
                           augment,
                           random_seed,
                           valid_size=0.1,
                           shuffle=True):
    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms
    valid_transform = transforms.Compose([
            transforms.Resize((128,128)),
            transforms.ToTensor(),
            normalize,
    ])
    if augment:
        train_transform = transforms.Compose([
            transforms.Resize((128,128)),
            transforms.RandomCrop(120, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.Resize((227,227)),
            transforms.ToTensor(),
            normalize,
        ])

    # load the dataset
    train_dataset = datasets.EMNIST(
        root=data_dir, train=True,split='letters',
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.EMNIST(
        root=data_dir, train=True,split='letters',
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler)

    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler)

    return (train_loader, valid_loader)


def get_test_loader(data_dir,
                    batch_size,
                    shuffle=True):
    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    )

    # define transform
    transform = transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ToTensor(),
        normalize,
    ])

    dataset = datasets.EMNIST(
        root=data_dir, train=False,
        download=True, split='letters',transform=transform,
    )

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle
    )

    return data_loader


# dataset
train_loader, valid_loader = get_train_valid_loader(data_dir = './data_emnist',                                      batch_size = 64,
                       augment = True,random_seed = 123)

test_loader = get_test_loader(data_dir = './data_emnist',
                              batch_size = 72)
# Out:
# Downloading https://www.nist.gov/itl to ./data_emnist/EMNIST/raw/gzip.zip
# 100%|██████████| 113071/113071 [00:00<00:00, 4540098.48it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 93
#      89     return data_loader
#      92 # dataset
# ---> 93 train_loader, valid_loader = get_train_valid_loader(data_dir = './data_emnist',                                      batch_size = 64,
#      94                        augment = True,random_seed = 123)
#      96 test_loader = get_test_loader(data_dir = './data_emnist',
#      97                               batch_size = 72)
#
# Cell In[12], line 34, in get_train_valid_loader(data_dir, batch_size, augment, random_seed, valid_size, shuffle)
#      27     train_transform = transforms.Compose([
#      28         transforms.Resize((227,227)),
#      29         transforms.ToTensor(),
#      30         normalize,
#      31     ])
#      33 # load the dataset
# ---> 34 train_dataset = datasets.EMNIST(
#      35     root=data_dir, train=True,split='letters',
#      36     download=True, transform=train_transform,
#      37 )
#      39 valid_dataset = datasets.EMNIST(
#      40     root=data_dir, train=True,split='letters',
#      41     download=True, transform=valid_transform,
#      42 )
#      44 num_train = len(train_dataset)
#
# File ~/venv/lib/python3.10/site-packages/torchvision/datasets/mnist.py:297, in EMNIST.__init__(self, root, split, **kwargs)
#     295 self.training_file = self._training_file(split)
#     296 self.test_file = self._test_file(split)
# --> 297 super().__init__(root, **kwargs)
#     298 self.classes = self.classes_split_dict[self.split]
#
# File ~/venv/lib/python3.10/site-packages/torchvision/datasets/mnist.py:99, in MNIST.__init__(self, root, train, transform, target_transform, download)
#      96     return
#      98 if download:
# ---> 99     self.download()
#     101 if not self._check_exists():
#     102     raise RuntimeError("Dataset not found. You can use download=True to download it")
#
# File ~/venv/lib/python3.10/site-packages/torchvision/datasets/mnist.py:334, in EMNIST.download(self)
#     330     return
#     332 os.makedirs(self.raw_folder, exist_ok=True)
# --> 334 download_and_extract_archive(self.url, download_root=self.raw_folder, md5=self.md5)
#     335 gzip_folder = os.path.join(self.raw_folder, "gzip")
#     336 for gzip_file in os.listdir(gzip_folder):
#
# File ~/venv/lib/python3.10/site-packages/torchvision/datasets/utils.py:434, in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     431 if not filename:
#     432     filename = os.path.basename(url)
# --> 434 download_url(url, download_root, filename, md5)
#     436 archive = os.path.join(download_root, filename)
#     437 print(f"Extracting {archive} to {extract_root}")
#
# File ~/venv/lib/python3.10/site-packages/torchvision/datasets/utils.py:155, in download_url(url, root, filename, md5, max_redirect_hops)
#     153 # check integrity of downloaded file
#     154 if not check_integrity(fpath, md5):
# --> 155     raise RuntimeError("File not found or corrupted.")
#
# RuntimeError: File not found or corrupted.

# %%
class model(nn.Module):
    def __init__(self, num_classes=10):
        super(model, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(1024, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
num_classes = 10
num_epochs = 20
batch_size = 72
learning_rate = 0.001

model = model(num_classes).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


# Train the model
total_step = len(train_loader)

# %%
total_step = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

    # Validation
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs

        print('Accuracy of the network on the {} validation images: {} %'.format(5000, 100 * correct / total))
# Out:
# Epoch [1/20], Step [704/704], Loss: 1.5449
# Accuracy of the network on the 5000 validation images: 48.6 %
# Epoch [2/20], Step [704/704], Loss: 1.9616
# Accuracy of the network on the 5000 validation images: 56.22 %
# Epoch [3/20], Step [704/704], Loss: 0.8179
# Accuracy of the network on the 5000 validation images: 64.14 %
# Epoch [4/20], Step [704/704], Loss: 1.1671
# Accuracy of the network on the 5000 validation images: 68.78 %
# Epoch [5/20], Step [704/704], Loss: 1.0791
# Accuracy of the network on the 5000 validation images: 71.68 %
# Epoch [6/20], Step [704/704], Loss: 1.9419
# Accuracy of the network on the 5000 validation images: 71.62 %
# Epoch [7/20], Step [704/704], Loss: 0.4385
# Accuracy of the network on the 5000 validation images: 75.76 %
# Epoch [8/20], Step [704/704], Loss: 0.7781
# Accuracy of the network on the 5000 validation images: 77.96 %
# Epoch [9/20], Step [704/704], Loss: 0.3145
# Accuracy of the network on the 5000 validation images: 77.92 %
# Epoch [10/20], Step [704/704], Loss: 0.3871
# Accuracy of the network on the 5000 validation images: 77.82 %
# Epoch [11/20], Step [704/704], Loss: 0.5229
# Accuracy of the network on the 5000 validation images: 78.62 %
# Epoch [12/20], Step [704/704], Loss: 1.0238
# Accuracy of the network on the 5000 validation images: 80.28 %
# Epoch [13/20], Step [704/704], Loss: 0.3856
# Accuracy of the network on the 5000 validation images: 79.76 %
# Epoch [14/20], Step [704/704], Loss: 0.1849
# Accuracy of the network on the 5000 validation images: 80.74 %
# Epoch [15/20], Step [704/704], Loss: 0.2611
# Accuracy of the network on the 5000 validation images: 81.16 %
# Epoch [16/20], Step [704/704], Loss: 1.7632
# Accuracy of the network on the 5000 validation images: 81.82 %
# Epoch [17/20], Step [704/704], Loss: 0.3635
# Accuracy of the network on the 5000 validation images: 81.86 %
# Epoch [18/20], Step [704/704], Loss: 0.2521
# Accuracy of the network on the 5000 validation images: 81.34 %
# Epoch [19/20], Step [704/704], Loss: 0.5294
# Accuracy of the network on the 5000 validation images: 82.2 %
# Epoch [20/20], Step [704/704], Loss: 0.0253
# Accuracy of the network on the 5000 validation images: 83.3 %

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs

    print('Accuracy of the network on the {} test images: {} %'.format(10000, 100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 83.83 %
